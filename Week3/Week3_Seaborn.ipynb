# %%
#Improt libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Line plot
data = sns.load_dataset("flights")
sns.lineplot(data=data ,x="year" ,y="passengers")
plt.show()

# %%
#Swarm plot
data = sns.load_dataset("iris")
sns.swarmplot(x="species", y="petal_length", data=data)
plt.show()
# Out:
# c:\Users\mohan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Bar plot
data = sns.load_dataset("titanic")
sns.countplot(data=data , x="class")
plt.show()

# %%
#Scatter plot
data = sns.load_dataset("tips")
sns.scatterplot(data=data , x="total_bill",y="tip")
plt.show()

# %%
#Facet grid
data = sns.load_dataset("titanic")
g = sns.FacetGrid(data , col="sex")
g.map(sns.histplot, "age")
plt.show()

# %%
#Standard scale
iris = sns.load_dataset("iris")
g = sns.clustermap(iris.drop("species",axis=1),cmap="coolwarm",standard_scale=1)
plt.show()
